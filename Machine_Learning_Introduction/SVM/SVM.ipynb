# %% [markdown]
# # <font color='black'>Introduction to Machine Learning</font>
#
# ---
#
# ## <font color='black'>Contents</font>
#
# ---
#
# 1. [Set-Up](#Set-Up)
# 2. [Support Vector Machines](#SVMs)

# %% [markdown]
# ## <font color='black'>Set-Up</font>
#
# ---
#
# First we will import the packages that we will need throughout the notebook.

# %%
import os
import numpy as np
from matplotlib import pyplot
from scipy import optimize
from scipy.io import loadmat
import utils

# tells matplotlib to embed plots within the notebook
# %matplotlib inline

# %% [markdown]
# ## <font color='black'>Support Vector Machines</font>
#
# ---
# In this session, we will explore the use of support vector machines (SVMs).
# We will begin by with a 2D example dataset which can be separated by a linear boundary.

# %%
data = loadmat(os.path.join('data', 'data1.mat'))
X = data['X']
y = data['y'][:,0]

# Plot training data
utils.plotData(X, y)

# %% [markdown]
# In this dataset, the positives examples are easily separated from the negative examples by the gap between them.

# %% [markdown]
# We will now study the effect of the parameter $C$. It works similarly to $1/\lambda$, where $\lambda$ is the regularization parameter.
# Now we will train the SVM model with $C = 1$. We should find that the SVM puts the decision boundary in the gap between the two populations missclassifying the data point on the far left.
#
# We can try now different values of $C$. In other words we can hange the value of $C$ in the next cell to $C = 100$ and run the SVM training again. For $C = 100$, we will find that the SVM classifies every example correctly.

# %%
for i in range(5):
    model = utils.svmTrain(X, y, (i+1)*30, utils.linearKernel, 1e-3, 20)
    utils.visualizeBoundaryLinear(X, y, model)

# %% [markdown]
# ### SVMs with Gaussian Kernels
#
# We will use now SVMs for non-linear classification. In particular, SVMs with Gaussian kernels will be exploited on datasets that are not linearly separable.
#
# #### Gaussian Kernel
#
# In order to obtain non-linear decision boundaries with the SVM, we need to first implement a Gaussian kernel. We defined the Gaussian kernel as a similarity function between a pair of examples,
# ($x^{(i)}$, $x^{(j)}$). The Gaussian kernel is parameterized by $\sigma$, which determines how fast the similarity metric decreases as the examples are further apart.
#
# Complete the code in `gaussianKernel`.

# %%
def gaussianKernel(x1, x2, sigma):
    """
    Computes the radial basis function
    Returns a radial basis function kernel between x1 and x2.
    
    Parameters
    ----------
    x1 :  numpy ndarray
        A vector of size (n, ), representing the first datapoint.
    
    x2 : numpy ndarray
        A vector of size (n, ), representing the second datapoint.
    
    sigma : float
        The bandwidth parameter for the Gaussian kernel.

    Returns
    -------
    sim : float
        The computed RBF between the two provided data points.
    
    Instructions
    ------------
    Fill in this function to return the similarity between `x1` and `x2`
    computed using a Gaussian kernel with bandwidth `sigma`.
    """
    sim = 0
    # ====================== CODE HERE ======================

    sim = np.exp((-np.sum((x1-x2)**2))/(2*sigma**2))

    # =============================================================
    return sim

# %% [markdown]
# Once we have completed the function `gaussianKernel` the following cell will test our kernel function on two provided examples and we should expect to see a value of 0.324652.

# %%
x1 = np.array([1, 2, 1])
x2 = np.array([0, 4, -1])
sigma = 2

sim = gaussianKernel(x1, x2, sigma)

print('Gaussian Kernel between x1 = [1, 2, 1], x2 = [0, 4, -1], sigma = %0.2f:'
      '\n\t%f\n(for sigma = 2, this value should be about 0.324652)\n' % (sigma, sim))
# Out:
# Gaussian Kernel between x1 = [1, 2, 1], x2 = [0, 4, -1], sigma = 2.00:
# 	0.324652
# (for sigma = 2, this value should be about 0.324652)

# %% [markdown]
# ### Example Dataset 2
#
# In the next part of this notebook we will work with dataset 2 displayed below.

# %%
# Load from ex6data2
# We will have X, y as keys in the dict data
data = loadmat(os.path.join('data', 'data2.mat'))
X = data['X']
y = data['y'][:, 0]

# Plot training data
utils.plotData(X, y)

# %% [markdown]
# From the figure, we can obserse that there is no linear decision boundary that separates the positive and negative examples for this dataset. However, by using the Gaussian kernel with the SVM, we will be able to learn a non-linear decision boundary that can perform reasonably well for the dataset. If we have correctly implemented the Gaussian kernel function, the following cell will proceed to train the SVM with the Gaussian kernel on this dataset.

# %%
# SVM Parameters
C = 1
sigma = 0.1

model= utils.svmTrain(X, y, C, gaussianKernel, args=(sigma,))
utils.visualizeBoundary(X, y, model)

# %% [markdown]
# ### Example dataset 3
# In this part of the exercise, we will gain more practical skills on how to use a SVM with a Gaussian kernel. The code below will load and display a third dataset

# %%
# Load from ex6data3
# We will have X, y as keys in the dict data
data = loadmat(os.path.join('data', 'data3.mat'))
X = data['X']
y = data['y'][:,0]
Xval = data['Xval']
yval = data['yval'][:, 0]

# Plot training data
utils.plotData(X, y)

# %% [markdown]
# We will be using the SVM with the Gaussian kernel with this dataset. In the provided dataset, data3.mat, we are given the variables X, y, Xval, yval. The provided code will train the SVM classifier using the training set (X,y) using parameters loaded from dataset3Params
#     Our task is to use the cross validation set Xval, yval to determine the best  and  parameter to use. We should write any additional code necessary to help searching over the parameters $C$ and $\sigma$ . For both $C$ and $\sigma$ we suggest trying values in multiplicative steps (e.g., 0.01, 0.03, 0.1, 0.3, 1, 3, 10, 30). Note that we should try all possible pairs of values for $C$ and $\sigma$ (e.g., $C=0.3$ and $\sigma=0.1$). For example, if we try each of the 8 values listed above for $C$ and for $\sigma^2$ , we would end up training and evaluating (on the cross validation set) a total of $8^2 = 64 $ different models. After we have determined the best $C$ and $\sigma$ parameters to use, we should modify the code in dataset3Params, filling in the best parameters.
#
# Implementation Help: When implementing cross validation to select the best $C$ and $\sigma$ parameter to use, we need to evaluate the error on the cross validation set. Recall that for classification, the error is defined as the fraction of the cross validation examples that were classified incorrectly. In python, we can compute this error using np.mean(predictions != yval) * 100), where predictions is a vector containing all the predictions from the SVM, and yval are the true labels from the cross validation set. We can use the svmPredict function to generate the predictions for the cross validation set.

# %%
def dataset3Params(X, y, Xval, yval):
    #DATASET3PARAMS returns our choice of C and sigma for Part 3 of the exercise
    #where we select the optimal (C, sigma) learning parameters to use for SVM with RBF kernel
    #[C, sigma] = DATASET3PARAMS(X, y, Xval, yval) returns our choice of C and 
    #sigma. We should complete this function to return the optimal C and 
    #sigma based on a cross-validation set.


   #We need to return the following variables correctly.
    C = 1
    sigma = 0.3
    # ====================== CODE HERE ======================
   
    Sl = Cl = [0.01,0.03,0.1,0.3,1,3,10,30]
    errorxval = np.zeros((len(Sl),len(Sl)))

    for C_i in range(len(Cl)):
        for S_i in range(len(Sl)):
            print('...',(C_i*8+S_i)*100/(len(Cl)*len(Sl)),'%', end='') 
            model = utils.svmTrain(X, y, Cl[C_i], gaussianKernel, args = (Sl[S_i],))
            pred = utils.svmPredict(model, Xval)
            errorxval[C_i,S_i] = np.mean(pred != yval)
                 
    dxm = np.unravel_index(np.argmin(errorxval, axis = None), errorxval.shape) 
    C = Cl[dxm[0]]
    sigma = Sl[dxm[1]]


    # =============================================================
    return C, sigma

# %%
C, sigma = dataset3Params(X, y, Xval, yval)
# Out:
# ... 0.0 %... 1.5625 %... 3.125 %... 4.6875 %... 6.25 %... 7.8125 %... 9.375 %... 10.9375 %... 12.5 %... 14.0625 %... 15.625 %... 17.1875 %... 18.75 %... 20.3125 %... 21.875 %... 23.4375 %... 25.0 %... 26.5625 %... 28.125 %... 29.6875 %... 31.25 %... 32.8125 %... 34.375 %... 35.9375 %... 37.5 %... 39.0625 %... 40.625 %... 42.1875 %... 43.75 %... 45.3125 %... 46.875 %... 48.4375 %... 50.0 %... 51.5625 %... 53.125 %... 54.6875 %... 56.25 %... 57.8125 %... 59.375 %... 60.9375 %... 62.5 %... 64.0625 %... 65.625 %... 67.1875 %... 68.75 %... 70.3125 %... 71.875 %... 73.4375 %... 75.0 %... 76.5625 %... 78.125 %... 79.6875 %... 81.25 %... 82.8125 %... 84.375 %... 85.9375 %... 87.5 %... 89.0625 %... 90.625 %... 92.1875 %... 93.75 %... 95.3125 %... 96.875 %... 98.4375 %

# %%
model= utils.svmTrain(X, y, C, gaussianKernel, args=(sigma,))
utils.visualizeBoundary(X, y, model)
